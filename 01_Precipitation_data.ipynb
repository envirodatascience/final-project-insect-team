# %% [markdown]
# <a href="https://colab.research.google.com/github/envirodatascience/final-project-insect-team/blob/main/01_Precipitation_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1: Import modules, read in data

# %%
# load the pandas package and read in the data frame
import pandas as pd
url = 'https://www.ncei.noaa.gov/orders/cdo/3997103.csv'
df = pd.read_csv(url)

# %% [markdown]
# ## 1.1 Look into the data

# %%
# first rows of the data
df.head()
# Out:
#        STATION               NAME  LATITUDE  LONGITUDE  ELEVATION  DATE   PRCP
# 0  USC00067002  ROUND POND, CT US   41.3008   -73.5369      243.8  1949  38.41
# 1  USC00067002  ROUND POND, CT US   41.3008   -73.5369      243.8  1950  47.65
# 2  USC00067002  ROUND POND, CT US   41.3008   -73.5369      243.8  1951  54.05
# 3  USC00067002  ROUND POND, CT US   41.3008   -73.5369      243.8  1952  60.71
# 4  USC00067002  ROUND POND, CT US   41.3008   -73.5369      243.8  1953  49.63

# %%
# the types of columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3910 entries, 0 to 3909
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATION    3910 non-null   object
#  1   NAME       3910 non-null   object
#  2   LATITUDE   3910 non-null   float64
#  3   LONGITUDE  3910 non-null   float64
#  4   ELEVATION  3910 non-null   float64
#  5   DATE       3910 non-null   int64
#  6   PRCP       3364 non-null   float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 214.0+ KB

# %%
# the shape of the data
df.shape
# Out:
# (3910, 7)

# %%
# column names
df.columns
# Out:
# Index(['STATION', 'NAME', 'LATITUDE', 'LONGITUDE', 'ELEVATION', 'DATE', 'PRCP',
#        'PRCP_ATTRIBUTES'],
#       dtype='object')

# %% [markdown]
# # Describing the Data

# %%
df.describe()
# Out:
#           LATITUDE    LONGITUDE    ELEVATION         DATE         PRCP
# count  3910.000000  3910.000000  3910.000000  3910.000000  3364.000000
# mean     41.586961   -72.837674   116.722532  1972.158568    48.063199
# std       0.264447     0.494189    96.809515    33.756201     8.827999
# min      41.062171   -73.700000     0.900000  1858.000000    18.350000
# 25%      41.350240   -73.229600    46.000000  1952.000000    42.010000
# 50%      41.583300   -72.933330    91.400000  1969.000000    47.275000
# 75%      41.795100   -72.392810   167.600000  1999.000000    53.712500
# max      42.027433   -71.830421   438.900000  2025.000000    88.520000

# %% [markdown]
# # Handle missing data

# %%
# find missing data
df.isnull().sum()
# Out:
# STATION        0
# NAME           0
# LATITUDE       0
# LONGITUDE      0
# ELEVATION      0
# DATE           0
# PRCP         546
# dtype: int64

# %%
# find rows with the NAs
df[df.isna().any(axis=1)]
# Out:
#           STATION                     NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 41    USC00067002        ROUND POND, CT US  41.30080  -73.53690      243.8
# 74    USC00069783      WOODBURY 3 W, CT US  41.56667  -73.26667      285.0
# 76    USC00067361     DERBY SHELTON, CT US  41.31667  -73.08333       18.0
# 77    USC00067361     DERBY SHELTON, CT US  41.31667  -73.08333       18.0
# 78    USC00067361     DERBY SHELTON, CT US  41.31667  -73.08333       18.0
# ...           ...                      ...       ...        ...        ...
# 3841  USC00064767    MIDDLETOWN 4 W, CT US  41.55000  -72.71667      112.5
# 3846  USC00064767    MIDDLETOWN 4 W, CT US  41.55000  -72.71667      112.5
# 3848  USC00060961  BULLS BRIDGE DAM, CT US  41.67630  -73.50860       79.2
# 3867  USC00060961  BULLS BRIDGE DAM, CT US  41.67630  -73.50860       79.2
# 3889  USC00060961  BULLS BRIDGE DAM, CT US  41.67630  -73.50860       79.2
#
#       DATE  PRCP
# 41    1999   NaN
# 74    1965   NaN
# 76    1887   NaN
# 77    1888   NaN
# 78    1889   NaN
# ...    ...   ...
# 3841  1992   NaN
# 3846  1997   NaN
# 3848  1952   NaN
# 3867  1971   NaN
# 3889  1994   NaN
#
# [546 rows x 7 columns]

# %%
# group by year of the NAs
df[df.isna().any(axis=1)].groupby('DATE').count()
# Out:
#       STATION  NAME  LATITUDE  LONGITUDE  ELEVATION  PRCP
# DATE
# 1884        1     1         1          1          1     0
# 1885        2     2         2          2          2     0
# 1886        2     2         2          2          2     0
# 1887        2     2         2          2          2     0
# 1888        2     2         2          2          2     0
# ...       ...   ...       ...        ...        ...   ...
# 2021        3     3         3          3          3     0
# 2022        3     3         3          3          3     0
# 2023        2     2         2          2          2     0
# 2024        4     4         4          4          4     0
# 2025        9     9         9          9          9     0
#
# [135 rows x 6 columns]

# %%
# drop NAs - we want yearly averages for CT ultimately, so NAs don't add anything for us
df.dropna(inplace=True)

# %%
# Rename some columns
# rename STATION to STATION_ID,NAME TO STATION_NAME
df.rename(columns={'STATION': 'STATION_ID', 'NAME': 'STATION_NAME'}, inplace=True)

# %% [markdown]
# # Calculating average precipitation per year

# %%
# average, minimum, and maximum precipitation per year
df_avg = df.groupby('DATE').agg(PAVG = ('PRCP', 'mean'),
                                PMIN = ('PRCP', 'min'),
                                PMAX = ('PRCP', 'max')).reset_index()
df_avg.head()
# Out:
#    DATE   PAVG   PMIN   PMAX
# 0  1858  41.89  41.89  41.89
# 1  1859  53.31  53.31  53.31
# 2  1860  37.38  37.38  37.38
# 3  1861  47.03  47.03  47.03
# 4  1862  48.02  48.02  48.02

# %%
# save dataset to runtime
df_avg.to_csv('noaa_precip_yearly_ct.csv', index=False)
