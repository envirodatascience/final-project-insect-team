# %% [markdown]
# <a href="https://colab.research.google.com/github/envirodatascience/final-project-insect-team/blob/main/03_ypm_insect_downloading_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook overview
# This notebook loads in entomology data from YPM via pygbif, cleans the dataset, and summarizes it into a dataset with insect richness (number of species) and abundance (number of occurrences) by state and year, broken down by assorted taxonomies.

# %% [markdown]
# # Dataset description
# A detailed description can be found [here](https://www.gbif.org/dataset/96404cc2-f762-11e1-a439-00145eb45e9a), but in short, this dataset comprises all insect specimens collected by researchers affiliated with the Yale Peabody Museum or specimens donated to the museum collections. The majority of specimens are Lepidoptera (butterflies) and other terrestrial insects. A small subset are aquatic insects. The dataset includes specimens from all continents except Antarctica and the earliest specimen was collected in 1656, although most records are from after 1900.
#
# Dataset citation: GBIF.org (02 April 2025) GBIF Occurrence Download  https://doi.org/10.15468/dl.y6dcyx

# %% [markdown]
# # Dataset loading and cleaning
# Install pygbif and load in modules

# %% [markdown]
# ## Load modules

# %%
# need to install pygbif module
# !pip install pygbif
# Out:
# Collecting pygbif
#   Downloading pygbif-0.6.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests>2.7 in /usr/local/lib/python3.11/dist-packages (from pygbif) (2.32.3)
# Collecting requests-cache (from pygbif)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting geojson_rewind (from pygbif)
#   Downloading geojson_rewind-1.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting geomet (from pygbif)
#   Downloading geomet-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting appdirs>=1.4.3 (from pygbif)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from pygbif) (3.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>2.7->pygbif) (2025.1.31)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from geomet->pygbif) (8.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->pygbif) (2.8.2)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.11/dist-packages (from requests-cache->pygbif) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache->pygbif)
#   Downloading cattrs-24.1.3-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests-cache->pygbif) (4.3.7)
# Collecting url-normalize>=1.4 (from requests-cache->pygbif)
#   Downloading url_normalize-2.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->pygbif) (1.17.0)
# Downloading pygbif-0.6.5-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 1.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading geojson_rewind-1.1.0-py3-none-any.whl (5.2 kB)
# Downloading geomet-1.1.0-py3-none-any.whl (31 kB)
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.3 MB/s eta 0:00:00
# Downloading cattrs-24.1.3-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 4.6 MB/s eta 0:00:00
# Downloading url_normalize-2.2.0-py3-none-any.whl (14 kB)
# Installing collected packages: appdirs, url-normalize, geomet, geojson_rewind, cattrs, requests-cache, pygbif
# Successfully installed appdirs-1.4.4 cattrs-24.1.3 geojson_rewind-1.1.0 geomet-1.1.0 pygbif-0.6.5 requests-cache-1.2.1 url-normalize-2.2.0

# %%
# import modules
import pandas as pd
import numpy as np

#from pygbif import occurrences as occ # I think we only need the occurrences module

from google.colab import userdata # for accessing username and password stored in environment variables

# Plotting
from plotnine import *
import plotnine
from mizani.formatters import scientific_format, percent_format, currency_format

# Stats
import statsmodels.api as sm
import scipy.stats as stats

# %% [markdown]
# ## Download YPM ENT data
# Using pygbif and the known institution and collection codes, we can download all insect data collected by the Peabody using my (Julia's) personal GBIF account credentials to download the most up to date dataset.
#
# Note that we could further refine the download to certain geographic areas or taxa, but for now want the full dataset.

# %%
# download ypm ent data
ent = occ.download(['institutionCode = YPM', 'collectionCode = ENT'], pred_type ='and',
                      user=userdata.get('GBIF_USER'), pwd=userdata.get('GBIF_PWD'), email='portmajm@gmail.com') # i think these should be able to be read in without stating?

# %%
ent # will send an email when the download is ready
# Out:
# ('0000426-250402121839773',
#  {'creator': 'portmajm',
#   'notification_address': ['portmajm@gmail.com'],
#   'sendNotification': True,
#   'predicate': {'type': 'and',
#    'predicates': [{'type': 'equals',
#      'key': 'INSTITUTION_CODE',
#      'value': 'YPM'},
#     {'type': 'equals', 'key': 'COLLECTION_CODE', 'value': 'ENT'}]},
#   'format': 'SIMPLE_CSV'})

# %% [markdown]
# I have not confirmed, but I think that if you have the pygbif module downloaded, anyone can get the dataset with the following code. The raw dataset is too big to load to GitHub but I can share it elsewhere if needed.

# %%
# use the key at top of previous chunk for downloading file
# this key will stay the same, so can start at this step in the future
occ.download_get(key='0000426-250402121839773')
# Out:
# {'path': './0000426-250402121839773.zip',
#  'size': 70743130,
#  'key': '0000426-250402121839773'}

# %%
# !ls
# Out:
# 0000426-250402121839773.zip  sample_data

# %%
# !unzip 0000426-250402121839773.zip
# Out:
# Archive:  0000426-250402121839773.zip
#   inflating: 0000426-250402121839773.csv

# %%
# !ls
# Out:
# 0000426-250402121839773.csv  0000426-250402121839773.zip  sample_data

# %%
# read in dataset
df_ent = pd.read_csv('0000426-250402121839773.csv', index_col = False,sep="\t")
# Out:
# <ipython-input-6-4a0bf1807e53>:2: DtypeWarning: Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ent = pd.read_csv('0000426-250402121839773.csv', index_col = False,sep="\t")

# %% [markdown]
# ## Explore dataset, identify cleaning needs

# %%
df_ent.head()
# Out:
#        gbifID                            datasetKey  \
# 0  3913895301  96404cc2-f762-11e1-a439-00145eb45e9a
# 1  1438048515  96404cc2-f762-11e1-a439-00145eb45e9a
# 2  1838432720  96404cc2-f762-11e1-a439-00145eb45e9a
# 3  1935872503  96404cc2-f762-11e1-a439-00145eb45e9a
# 4  2565549387  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                     occurrenceID   kingdom      phylum  \
# 0  urn:uuid:00006775-753e-4ed0-bbe6-0702cae6c26b  Animalia  Arthropoda
# 1  urn:uuid:000426c2-4fff-44bf-97c3-461d8022c177  Animalia  Arthropoda
# 2  urn:uuid:00091984-cf96-4498-a6c6-e034f72a355a  Animalia  Arthropoda
# 3  urn:uuid:0009a4ea-0d53-46da-bf70-949145977b1b  Animalia  Arthropoda
# 4  urn:uuid:000a73bd-10b3-46d3-b38c-be8c3d909b83  Animalia  Arthropoda
#
#      class        order        family         genus                  species  \
# 0  Insecta  Lepidoptera  Papilionidae       Papilio        Papilio polyxenes
# 1  Insecta  Lepidoptera     Noctuidae       Achatia           Achatia evicta
# 2  Insecta  Lepidoptera   Geometridae     Lobophora     Lobophora nivigerata
# 3  Insecta  Lepidoptera   Geometridae  Metarranthis  Metarranthis amyrisaria
# 4  Insecta  Lepidoptera     Crambidae     Parapoynx     Parapoynx obscuralis
#
#    ... identifiedBy dateIdentified  license         rightsHolder  \
# 0  ...          NaN            NaN  CC0_1_0  Yale Peabody Museum
# 1  ...          NaN            NaN  CC0_1_0  Yale Peabody Museum
# 2  ...          NaN            NaN  CC0_1_0  Yale Peabody Museum
# 3  ...          NaN            NaN  CC0_1_0  Yale Peabody Museum
# 4  ...          NaN            NaN  CC0_1_0  Yale Peabody Museum
#
#                               recordedBy typeStatus establishmentMeans  \
# 0                             R. T. Cail        NaN                NaN
# 1                        Richard E. Gray        NaN                NaN
# 2                     David S. MacDonald        NaN                NaN
# 3  Timothy L. McCabe, Dale F. Schweitzer        NaN                NaN
# 4                      Herman P. Wilhelm        NaN                NaN
#
#             lastInterpreted mediaType  \
# 0  2025-04-01T13:31:34.353Z       NaN
# 1  2025-04-01T13:31:34.410Z       NaN
# 2  2025-04-01T13:31:25.822Z       NaN
# 3  2025-04-01T13:31:34.328Z       NaN
# 4  2025-04-01T13:31:34.426Z       NaN
#
#                                                issue
# 0  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 1  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 2  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 3  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 4  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [5 rows x 50 columns]

# %%
df_ent.info()

# note that coordinatePrecision, depth, depthAccuracy, establishmentMeans are all null, recordNumber, typeStatus are mostly null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421950 entries, 0 to 421949
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   gbifID                            421950 non-null  int64
#  1   datasetKey                        421950 non-null  object
#  2   occurrenceID                      421950 non-null  object
#  3   kingdom                           421950 non-null  object
#  4   phylum                            421438 non-null  object
#  5   class                             421424 non-null  object
#  6   order                             421394 non-null  object
#  7   family                            420948 non-null  object
#  8   genus                             415811 non-null  object
#  9   species                           392092 non-null  object
#  10  infraspecificEpithet              3666 non-null    object
#  11  taxonRank                         421950 non-null  object
#  12  scientificName                    421950 non-null  object
#  13  verbatimScientificName            421950 non-null  object
#  14  verbatimScientificNameAuthorship  395834 non-null  object
#  15  countryCode                       419606 non-null  object
#  16  locality                          403461 non-null  object
#  17  stateProvince                     400024 non-null  object
#  18  occurrenceStatus                  421950 non-null  object
#  19  individualCount                   421950 non-null  int64
#  20  publishingOrgKey                  421950 non-null  object
#  21  decimalLatitude                   401528 non-null  float64
#  22  decimalLongitude                  401528 non-null  float64
#  23  coordinateUncertaintyInMeters     400576 non-null  float64
#  24  coordinatePrecision               0 non-null       float64
#  25  elevation                         54736 non-null   float64
#  26  elevationAccuracy                 4662 non-null    float64
#  27  depth                             0 non-null       float64
#  28  depthAccuracy                     0 non-null       float64
#  29  eventDate                         393582 non-null  object
#  30  day                               350907 non-null  float64
#  31  month                             382949 non-null  float64
#  32  year                              393186 non-null  float64
#  33  taxonKey                          421950 non-null  int64
#  34  speciesKey                        392092 non-null  float64
#  35  basisOfRecord                     421950 non-null  object
#  36  institutionCode                   421950 non-null  object
#  37  collectionCode                    421950 non-null  object
#  38  catalogNumber                     421950 non-null  object
#  39  recordNumber                      4 non-null       object
#  40  identifiedBy                      26991 non-null   object
#  41  dateIdentified                    23519 non-null   object
#  42  license                           421950 non-null  object
#  43  rightsHolder                      421950 non-null  object
#  44  recordedBy                        360178 non-null  object
#  45  typeStatus                        342 non-null     object
#  46  establishmentMeans                0 non-null       float64
#  47  lastInterpreted                   421950 non-null  object
#  48  mediaType                         28782 non-null   object
#  49  issue                             421950 non-null  object
# dtypes: float64(13), int64(3), object(34)
# memory usage: 161.0+ MB

# %%
df_ent.value_counts('order').head(10)
# butterflies/moths, bees/wasps, flies, beetles, dragonflies/damselflies are the top 5 most recorded insect orders
# this is not surprising, given that these tend to be the most 'charismatic' of insects
# Out:
# order
# Lepidoptera    349114
# Hymenoptera     22832
# Diptera         19248
# Coleoptera      15547
# Odonata          6428
# Hemiptera        3655
# Ixodida          1056
# Trichoptera       773
# Neuroptera        601
# Psocodea          567
# Name: count, dtype: int64

# %%
df_ent[df_ent.stateProvince == 'Connecticut'].value_counts('order').head(10)
# pretty much mirrors the overall dataset
# Out:
# order
# Lepidoptera    51071
# Hymenoptera     4437
# Diptera         3486
# Coleoptera      2891
# Odonata         1020
# Trichoptera      712
# Neuroptera       508
# Hemiptera        478
# Megaloptera      221
# Psocodea         202
# Name: count, dtype: int64

# %%
df_ent.value_counts('family').head(10)
# Out:
# family
# Noctuidae       59120
# Erebidae        57480
# Nymphalidae     52609
# Geometridae     38142
# Papilionidae    23918
# Hesperiidae     23334
# Pieridae        19696
# Lycaenidae      19529
# Apidae          17807
# Sphingidae      13896
# Name: count, dtype: int64

# %% [markdown]
# ## Check that all records are actually insects

# %% [markdown]
# ### Check kingdoms

# %%
# check unique kingdoms - should all be Animalia
df_ent.kingdom.unique()
# not all Animalia, uh oh!
# Out:
# array(['Animalia', 'Chromista', 'Plantae', 'Protozoa', 'incertae sedis'],
#       dtype=object)

# %%
# check rows that are not animalia - are they incorrectly labelled or mistakenly included?
df_ent[df_ent.kingdom != 'Animalia']
# 78 non-Animalia records
# Out:
#             gbifID                            datasetKey  \
# 821     3045462302  96404cc2-f762-11e1-a439-00145eb45e9a
# 3363    3045462304  96404cc2-f762-11e1-a439-00145eb45e9a
# 5626    4007533327  96404cc2-f762-11e1-a439-00145eb45e9a
# 6663    3045462307  96404cc2-f762-11e1-a439-00145eb45e9a
# 21328   3045472317  96404cc2-f762-11e1-a439-00145eb45e9a
# ...            ...                                   ...
# 398178  1658217258  96404cc2-f762-11e1-a439-00145eb45e9a
# 399219  1039128077  96404cc2-f762-11e1-a439-00145eb45e9a
# 404490  3045474324  96404cc2-f762-11e1-a439-00145eb45e9a
# 406539  4007535485  96404cc2-f762-11e1-a439-00145eb45e9a
# 418796  4995733331  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                          occurrenceID         kingdom  \
# 821     urn:uuid:040df1fd-b07f-4f0b-be10-e83d77c4d46a       Chromista
# 3363    urn:uuid:10308dcf-fe54-4ff1-b0db-6612ca54f297       Chromista
# 5626    urn:uuid:1b6f8af9-531a-4825-b5a5-b6f946fd653d         Plantae
# 6663    urn:uuid:2063826e-f1b3-4a41-a745-49729f9ec1bf       Chromista
# 21328   urn:uuid:675ebd39-0b6c-4829-b311-1d10db619f7a        Protozoa
# ...                                               ...             ...
# 398178  urn:uuid:8c7573aa-e483-4e0a-85a0-4d6779409b15  incertae sedis
# 399219  urn:uuid:9188c741-7118-4f84-8b95-a101e480118e  incertae sedis
# 404490  urn:uuid:ab4695de-8e26-4684-83e5-030ba42ed147       Chromista
# 406539  urn:uuid:b58906ab-2ff6-4f11-a47c-64c9185686b3         Plantae
# 418796  urn:uuid:f09bf528-1375-47fe-9963-943af759d8b0         Plantae
#
#               phylum          class            order            family  \
# 821          Myzozoa   Aconoidasida   Haemospororida      Plasmodiidae
# 3363         Myzozoa   Aconoidasida   Haemospororida      Plasmodiidae
# 5626    Tracheophyta     Liliopsida           Poales           Poaceae
# 6663         Myzozoa   Aconoidasida   Haemospororida      Plasmodiidae
# 21328     Euglenozoa  Kinetoplastea  Trypanosomatida  Trypanosomatidae
# ...              ...            ...              ...               ...
# 398178           NaN            NaN              NaN               NaN
# 399219           NaN            NaN              NaN               NaN
# 404490       Myzozoa   Aconoidasida   Haemospororida      Plasmodiidae
# 406539  Tracheophyta     Liliopsida           Poales           Poaceae
# 418796  Tracheophyta     Liliopsida           Poales           Poaceae
#
#               genus species  ... identifiedBy dateIdentified  license  \
# 821      Plasmodium     NaN  ...          NaN            NaN  CC0_1_0
# 3363     Plasmodium     NaN  ...          NaN            NaN  CC0_1_0
# 5626            Zea     NaN  ...          NaN            NaN  CC0_1_0
# 6663     Plasmodium     NaN  ...          NaN            NaN  CC0_1_0
# 21328   Trypanosoma     NaN  ...          NaN            NaN  CC0_1_0
# ...             ...     ...  ...          ...            ...      ...
# 398178          NaN     NaN  ...          NaN            NaN  CC0_1_0
# 399219          NaN     NaN  ...          NaN            NaN  CC0_1_0
# 404490   Plasmodium     NaN  ...          NaN            NaN  CC0_1_0
# 406539          Zea     NaN  ...          NaN            NaN  CC0_1_0
# 418796          Zea     NaN  ...          NaN            NaN  CC0_1_0
#
#                rightsHolder  \
# 821     Yale Peabody Museum
# 3363    Yale Peabody Museum
# 5626    Yale Peabody Museum
# 6663    Yale Peabody Museum
# 21328   Yale Peabody Museum
# ...                     ...
# 398178  Yale Peabody Museum
# 399219  Yale Peabody Museum
# 404490  Yale Peabody Museum
# 406539  Yale Peabody Museum
# 418796  Yale Peabody Museum
#
#                                                recordedBy typeStatus  \
# 821                                                   NaN        NaN
# 3363                                                  NaN        NaN
# 5626                                          R. Godefroi        NaN
# 6663                                                  NaN        NaN
# 21328                                                 NaN        NaN
# ...                                                   ...        ...
# 398178                                     Lionel P. Grey        NaN
# 399219  Lawrence F. Gall, Raymond J. Pupedis, Nicole M...        NaN
# 404490                                                NaN        NaN
# 406539                                        R. Godefroi        NaN
# 418796                    Jeff M. Fengler, Chris T. Maier        NaN
#
#        establishmentMeans           lastInterpreted mediaType  \
# 821                   NaN  2025-04-01T13:31:36.022Z       NaN
# 3363                  NaN  2025-04-01T13:31:39.878Z       NaN
# 5626                  NaN  2025-04-01T13:31:42.697Z       NaN
# 6663                  NaN  2025-04-01T13:31:43.782Z       NaN
# 21328                 NaN  2025-04-01T13:31:56.927Z       NaN
# ...                   ...                       ...       ...
# 398178                NaN  2025-04-01T13:31:53.043Z       NaN
# 399219                NaN  2025-04-01T13:31:53.493Z       NaN
# 404490                NaN  2025-04-01T13:32:06.458Z       NaN
# 406539                NaN  2025-04-01T13:32:07.703Z       NaN
# 418796                NaN  2025-04-01T13:32:14.711Z       NaN
#
#                                                     issue
# 821     OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 3363    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 5626    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 6663    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 21328   OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# ...                                                   ...
# 398178  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 399219  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 404490  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 406539  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 418796  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [78 rows x 50 columns]

# %%
# which genera are present?
df_ent[df_ent.kingdom != 'Animalia'].genus.unique()
# Zea are grasses, Plasmodium and Trypanosoma are protozoa
# Out:
# array(['Plasmodium', 'Zea', 'Trypanosoma', nan], dtype=object)

# %%
# check families, trying to find the records that are nan genera
df_ent[df_ent.kingdom != 'Animalia'].family.unique()
# same taxa present
# Out:
# array(['Plasmodiidae', 'Poaceae', 'Trypanosomatidae', nan], dtype=object)

# %%
# check orders, trying to find the records that are nan families
df_ent[df_ent.kingdom != 'Animalia'].order.unique()
# same taxa present
# Out:
# array(['Haemospororida', 'Poales', 'Trypanosomatida', nan], dtype=object)

# %%
# check nan families
df_ent[df_ent.family.isnull()][df_ent.kingdom != 'Animalia'].kingdom.unique()
# all incertae sedis, aka unknown
# Out:
# <ipython-input-40-1ff1dd4eabfe>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_ent[df_ent.family.isnull()][df_ent.kingdom != 'Animalia'].kingdom.unique()
# array(['incertae sedis'], dtype=object)

# %% [markdown]
# From the above checks, we now know that the records labelled with kingdom != to Animalia are in fact not Animalia and should be removed. Next, we will check unique phyla within kingdom Animalia to see if all Animalia present are actually insects

# %% [markdown]
# ### Check phyla

# %%
# check unique Animalia phyla - should all be Arthopoda
df_ent[df_ent.kingdom == 'Animalia'].phylum.unique()
# of the animal records, Cnidaria (jellyfish) and Platyhelminthes (flatworms) are not insects
# Out:
# array(['Arthropoda', nan, 'Cnidaria', 'Platyhelminthes'], dtype=object)

# %%
# check null phyla
df_ent[df_ent.phylum.isnull()]
# those visible in preview are all insects, just looks like their taxonomy matching did not work
# will come back to this later in the notebook
# either need to ignore these records or manually add in at a mimimum order and family
# Out:
#             gbifID                            datasetKey  \
# 1325    1039030097  96404cc2-f762-11e1-a439-00145eb45e9a
# 1539    1039030291  96404cc2-f762-11e1-a439-00145eb45e9a
# 2382    2283526148  96404cc2-f762-11e1-a439-00145eb45e9a
# 2446    1039033276  96404cc2-f762-11e1-a439-00145eb45e9a
# 2753    1039035308  96404cc2-f762-11e1-a439-00145eb45e9a
# ...            ...                                   ...
# 419897  1039198488  96404cc2-f762-11e1-a439-00145eb45e9a
# 419980  2301952518  96404cc2-f762-11e1-a439-00145eb45e9a
# 420043  1039198684  96404cc2-f762-11e1-a439-00145eb45e9a
# 420355  1039199953  96404cc2-f762-11e1-a439-00145eb45e9a
# 421900  1039205062  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                          occurrenceID   kingdom phylum class  \
# 1325    urn:uuid:064e0a20-311a-443e-acef-326a5d7de581  Animalia    NaN   NaN
# 1539    urn:uuid:07618e5d-319b-4109-9800-da0dccd2908b  Animalia    NaN   NaN
# 2382    urn:uuid:0b5787d0-38e7-41c7-913d-8ef3d2fba135  Animalia    NaN   NaN
# 2446    urn:uuid:0bb94789-d2c7-4263-b4ac-7b933b77360e  Animalia    NaN   NaN
# 2753    urn:uuid:0d63752e-b0d8-4f1d-993a-40c9cec568fe  Animalia    NaN   NaN
# ...                                               ...       ...    ...   ...
# 419897  urn:uuid:f6272edb-d590-4a8e-9a35-20f39169ea9f  Animalia    NaN   NaN
# 419980  urn:uuid:f685909e-fe5f-4e22-aa61-acfad63329de  Animalia    NaN   NaN
# 420043  urn:uuid:f6c23321-4a4d-4f01-9220-300cf94f572c  Animalia    NaN   NaN
# 420355  urn:uuid:f858014d-4b6b-4cef-9d2e-af501b1be1ef  Animalia    NaN   NaN
# 421900  urn:uuid:ffca3fdc-bdbc-4cb8-91fd-0ff115b0a5f8  Animalia    NaN   NaN
#
#        order      family       genus             species  ... identifiedBy  \
# 1325     NaN         NaN  Nymphidium                 NaN  ...          NaN
# 1539     NaN         NaN       Caria           Caria ino  ...          NaN
# 2382     NaN  Scolytidae         NaN                 NaN  ...          NaN
# 2446     NaN         NaN  Calephelis                 NaN  ...          NaN
# 2753     NaN         NaN  Calephelis                 NaN  ...          NaN
# ...      ...         ...         ...                 ...  ...          ...
# 419897   NaN         NaN  Calephelis                 NaN  ...          NaN
# 419980   NaN         NaN  Calephelis                 NaN  ...          NaN
# 420043   NaN         NaN  Calephelis                 NaN  ...          NaN
# 420355   NaN         NaN       Caria           Caria ino  ...          NaN
# 421900   NaN         NaN  Nymphidium  Nymphidium baeotia  ...          NaN
#
#        dateIdentified  license         rightsHolder  \
# 1325              NaN  CC0_1_0  Yale Peabody Museum
# 1539              NaN  CC0_1_0  Yale Peabody Museum
# 2382              NaN  CC0_1_0  Yale Peabody Museum
# 2446              NaN  CC0_1_0  Yale Peabody Museum
# 2753              NaN  CC0_1_0  Yale Peabody Museum
# ...               ...      ...                  ...
# 419897            NaN  CC0_1_0  Yale Peabody Museum
# 419980            NaN  CC0_1_0  Yale Peabody Museum
# 420043            NaN  CC0_1_0  Yale Peabody Museum
# 420355            NaN  CC0_1_0  Yale Peabody Museum
# 421900            NaN  CC0_1_0  Yale Peabody Museum
#
#                                   recordedBy typeStatus establishmentMeans  \
# 1325                                     NaN        NaN                NaN
# 1539                        John R. Heitzman        NaN                NaN
# 2382                      Raymond J. Pupedis        NaN                NaN
# 2446          Don B. Stallings, J. E. Turner        NaN                NaN
# 2753          Don B. Stallings, J. E. Turner        NaN                NaN
# ...                                      ...        ...                ...
# 419897        Don B. Stallings, J. E. Turner        NaN                NaN
# 419980                     Victoria J. Mason        NaN                NaN
# 420043        Don B. Stallings, J. E. Turner        NaN                NaN
# 420355                     Herman P. Wilhelm        NaN                NaN
# 421900  Victor O. DeMasi, Roanna Z. Metowski        NaN                NaN
#
#                  lastInterpreted mediaType  \
# 1325    2025-04-01T13:31:36.910Z       NaN
# 1539    2025-04-01T13:31:37.201Z       NaN
# 2382    2025-04-01T13:31:38.364Z       NaN
# 2446    2025-04-01T13:31:38.520Z       NaN
# 2753    2025-04-01T13:31:39.057Z       NaN
# ...                          ...       ...
# 419897  2025-04-01T13:32:01.751Z       NaN
# 419980  2025-04-01T13:32:15.096Z       NaN
# 420043  2025-04-01T13:32:15.820Z       NaN
# 420355  2025-04-01T13:32:16.013Z       NaN
# 421900  2025-04-01T13:32:02.380Z       NaN
#
#                                                     issue
# 1325    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 1539    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 2382    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 2446    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 2753    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# ...                                                   ...
# 419897  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 419980  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 420043  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 420355  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 421900  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [512 rows x 50 columns]

# %%
# check platyhelminthes (flatworms)
df_ent[df_ent.phylum == 'Platyhelminthes']
# these are indeed all flatworms - not including because not technically insects.
# also, there are only 5 of them in the dataset
# Out:
#             gbifID                            datasetKey  \
# 25116   3059293353  96404cc2-f762-11e1-a439-00145eb45e9a
# 81261   3059288356  96404cc2-f762-11e1-a439-00145eb45e9a
# 200571  3059284388  96404cc2-f762-11e1-a439-00145eb45e9a
# 357823  3045475327  96404cc2-f762-11e1-a439-00145eb45e9a
# 377351  3059295319  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                          occurrenceID   kingdom  \
# 25116   urn:uuid:7a521935-c434-4e00-8d2a-99a1f5f2b2a7  Animalia
# 81261   urn:uuid:8ae0914c-a105-4c88-9a3d-81a5aec706e5  Animalia
# 200571  urn:uuid:cf23b693-b6d4-4c84-901e-274f1c5f48eb  Animalia
# 357823  urn:uuid:ca4f9b04-9c27-45ad-8fe3-96cb47c8913e  Animalia
# 377351  urn:uuid:2844c977-3306-49f7-895a-e4f9615e6711  Animalia
#
#                  phylum    class           order           family  \
# 25116   Platyhelminthes      NaN      Tricladida        Kenkiidae
# 81261   Platyhelminthes      NaN      Tricladida        Kenkiidae
# 200571  Platyhelminthes      NaN      Tricladida        Kenkiidae
# 357823  Platyhelminthes  Cestoda  Cyclophyllidea  Mesocestoididae
# 377351  Platyhelminthes      NaN      Tricladida        Kenkiidae
#
#                 genus                 species  ... identifiedBy  \
# 25116       Speophila                     NaN  ...          NaN
# 81261    Sphalloplana  Sphalloplana buchanani  ...          NaN
# 200571      Speophila                     NaN  ...          NaN
# 357823  Mesocestoides     Mesocestoides corti  ...          NaN
# 377351   Sphalloplana  Sphalloplana buchanani  ...          NaN
#
#        dateIdentified  license         rightsHolder  recordedBy typeStatus  \
# 25116             NaN  CC0_1_0  Yale Peabody Museum  R. McAdams        NaN
# 81261             NaN  CC0_1_0  Yale Peabody Museum  R. McAdams        NaN
# 200571            NaN  CC0_1_0  Yale Peabody Museum  R. McAdams        NaN
# 357823            NaN  CC0_1_0  Yale Peabody Museum         NaN        NaN
# 377351            NaN  CC0_1_0  Yale Peabody Museum  R. McAdams        NaN
#
#        establishmentMeans           lastInterpreted   mediaType  \
# 25116                 NaN  2025-04-01T13:31:59.698Z  StillImage
# 81261                 NaN  2025-04-01T13:32:02.134Z  StillImage
# 200571                NaN  2025-04-01T13:32:10.689Z  StillImage
# 357823                NaN  2025-04-01T13:32:10.518Z         NaN
# 377351                NaN  2025-04-01T13:31:45.525Z  StillImage
#
#                                                     issue
# 25116   OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 81261   OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 200571  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 357823  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 377351  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [5 rows x 50 columns]

# %%
# check Cnidaria (jellyfish)
df_ent[df_ent.phylum == 'Cnidaria']
# all Eurybea -- butterflies, not jellyfish
# will need to manually change the phylum, add in family/order/class
# only 10 instances, not a big deal to fix
# Out:
#             gbifID                            datasetKey  \
# 4336    1039040579  96404cc2-f762-11e1-a439-00145eb45e9a
# 27260   1065086402  96404cc2-f762-11e1-a439-00145eb45e9a
# 36320   1039150165  96404cc2-f762-11e1-a439-00145eb45e9a
# 71692   1039090759  96404cc2-f762-11e1-a439-00145eb45e9a
# 96737   1065086478  96404cc2-f762-11e1-a439-00145eb45e9a
# 120843  1064377420  96404cc2-f762-11e1-a439-00145eb45e9a
# 189550  1039134539  96404cc2-f762-11e1-a439-00145eb45e9a
# 226389  1064377421  96404cc2-f762-11e1-a439-00145eb45e9a
# 343124  1039117552  96404cc2-f762-11e1-a439-00145eb45e9a
# 348294  2301952151  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                          occurrenceID   kingdom    phylum  \
# 4336    urn:uuid:1506fdb9-44be-4ba0-a9ce-69e85003fdf3  Animalia  Cnidaria
# 27260   urn:uuid:84e16475-693b-4c32-8b9c-fdcb7372c243  Animalia  Cnidaria
# 36320   urn:uuid:b0b53e26-fc42-4409-a07d-8ff7f8720966  Animalia  Cnidaria
# 71692   urn:uuid:5c53d724-6861-4449-9668-c9d3c45b69ed  Animalia  Cnidaria
# 96737   urn:uuid:d5e0ed06-6b35-4196-9ef5-58db2b0d554d  Animalia  Cnidaria
# 120843  urn:uuid:4bd36197-95ab-4b7c-b50d-3799e443c838  Animalia  Cnidaria
# 189550  urn:uuid:9a272754-65ea-474f-84b7-0cebb8e9557d  Animalia  Cnidaria
# 226389  urn:uuid:4c9298b0-c881-49b1-b2b0-6c4d28a62c59  Animalia  Cnidaria
# 343124  urn:uuid:824fb2d0-5076-4a1b-ba55-b2f979da62a2  Animalia  Cnidaria
# 348294  urn:uuid:9b8e6fa2-f7a0-4d22-9348-1f4379e359ad  Animalia  Cnidaria
#
#        class order family    genus               species  ... identifiedBy  \
# 4336     NaN   NaN    NaN  Eurybia        Eurybia elvina  ...          NaN
# 27260    NaN   NaN    NaN  Eurybia        Eurybia elvina  ...          NaN
# 36320    NaN   NaN    NaN  Eurybia  Eurybia latifasciata  ...          NaN
# 71692    NaN   NaN    NaN  Eurybia        Eurybia elvina  ...          NaN
# 96737    NaN   NaN    NaN  Eurybia        Eurybia elvina  ...          NaN
# 120843   NaN   NaN    NaN  Eurybia        Eurybia elvina  ...          NaN
# 189550   NaN   NaN    NaN  Eurybia       Eurybia pergaea  ...          NaN
# 226389   NaN   NaN    NaN  Eurybia        Eurybia elvina  ...          NaN
# 343124   NaN   NaN    NaN  Eurybia        Eurybia elvina  ...          NaN
# 348294   NaN   NaN    NaN  Eurybia      Eurybia halimede  ...          NaN
#
#        dateIdentified  license         rightsHolder  \
# 4336              NaN  CC0_1_0  Yale Peabody Museum
# 27260             NaN  CC0_1_0  Yale Peabody Museum
# 36320             NaN  CC0_1_0  Yale Peabody Museum
# 71692             NaN  CC0_1_0  Yale Peabody Museum
# 96737             NaN  CC0_1_0  Yale Peabody Museum
# 120843            NaN  CC0_1_0  Yale Peabody Museum
# 189550            NaN  CC0_1_0  Yale Peabody Museum
# 226389            NaN  CC0_1_0  Yale Peabody Museum
# 343124            NaN  CC0_1_0  Yale Peabody Museum
# 348294            NaN  CC0_1_0  Yale Peabody Museum
#
#                                   recordedBy typeStatus establishmentMeans  \
# 4336                        Robert A. Raguso        NaN                NaN
# 27260   Victor O. DeMasi, Roanna Z. Metowski        NaN                NaN
# 36320   Victor O. DeMasi, Roanna Z. Metowski        NaN                NaN
# 71692                       Robert A. Raguso        NaN                NaN
# 96737   Victor O. DeMasi, Roanna Z. Metowski        NaN                NaN
# 120843  Victor O. DeMasi, Roanna Z. Metowski        NaN                NaN
# 189550                        Fritz Plaumann        NaN                NaN
# 226389  Victor O. DeMasi, Roanna Z. Metowski        NaN                NaN
# 343124                      Robert A. Raguso        NaN                NaN
# 348294                     Victoria J. Mason        NaN                NaN
#
#                  lastInterpreted   mediaType  \
# 4336    2025-04-01T13:31:41.234Z  StillImage
# 27260   2025-04-01T13:32:01.174Z         NaN
# 36320   2025-04-01T13:31:56.426Z  StillImage
# 71692   2025-04-01T13:31:55.345Z         NaN
# 96737   2025-04-01T13:32:11.636Z         NaN
# 120843  2025-04-01T13:31:52.503Z         NaN
# 189550  2025-04-01T13:32:04.201Z  StillImage
# 226389  2025-04-01T13:31:52.368Z         NaN
# 343124  2025-04-01T13:32:01.090Z         NaN
# 348294  2025-04-01T13:31:54.374Z  StillImage
#
#                                                     issue
# 4336    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 27260   OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 36320   OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 71692   OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 96737   OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 120843  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 189550  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 226389  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 343124  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 348294  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [10 rows x 50 columns]

# %% [markdown]
# In the above chunks, we determined that the ~500 rows with null phyla look to primarily be real insects, should have their family/order/class added in manually where possible. The rows with phylum Platyhelminthes are indeed flatworm records, which do not fall under our definition of insect here and will be removed. The rows with phylum Cnidaria are NOT jellyfish but rather butterflies, so we will fix their taxonomies.
#
# Next, we will do one last check of orders in the dataset to see if we're missing any other issues

# %% [markdown]
# ### Check orders

# %%
# check unique orders
df_ent[(df_ent.kingdom == 'Animalia') & (df_ent.phylum == 'Arthropoda')].order.unique()
# all good!
# Out:
# array(['Lepidoptera', 'Hymenoptera', 'Diptera', 'Odonata', 'Coleoptera',
#        'Ixodida', 'Hemiptera', 'Megaloptera', 'Orthoptera', 'Trichoptera',
#        'Trombidiformes', 'Neuroptera', 'Araneae', 'Psocodea', nan,
#        'Siphonaptera', 'Mesostigmata', 'Mecoptera', 'Sarcoptiformes',
#        'Scolopendromorpha', 'Ephemeroptera', 'Thysanoptera',
#        'Entomobryomorpha', 'Mantodea', 'Opiliones', 'Raphidioptera',
#        'Scorpiones', 'Blattodea', 'Solifugae', 'Dermaptera', 'Plecoptera',
#        'Spirobolida', 'Amblypygi', 'Uropygi', 'Pseudoscorpiones',
#        'Phasmida', 'Poduromorpha'], dtype=object)

# %% [markdown]
# ## Check occurrence types

# %%
# are any records not recorded as present
df_ent.occurrenceStatus.unique()
# only value is 'present', so no cleaning needed
# Out:
# array(['PRESENT'], dtype=object)

# %% [markdown]
# ## Clean dataset

# %% [markdown]
# Issues to clean:
# * remove records in Plantae, Chromista, Protozoa, uncertain
# * remove records in Platyhelminthes
# * remove columns which are all or mostly NA
# * subset to US only
# * remove very old records -- too uncertain
# * update taxonomies where phylum is nan but genus/family etc is correct
# * fix taxonomy for butterflies listed in Cnidaria
# * check for typos? may be challenging

# %% [markdown]
# ### Remove records in non-insect kingdoms, phyla

# %%
# remove rows in 'Chromista', 'Plantae', 'Protozoa', 'incertae sedis'
df_ent_sub1 = df_ent[~df_ent.kingdom.isin(['Chromista', 'Plantae', 'Protozoa', 'incertae sedis'])]
# could just say != Animalia, but want to be explicit here
df_ent_sub1.kingdom.unique() # looks good
# Out:
# array(['Animalia'], dtype=object)

# %%
# remove platyhelminthes
df_ent_sub2 = df_ent_sub1[df_ent_sub1.phylum != 'Platyhelminthes']
df_ent_sub2.phylum.unique() # looks good - will deal with cnidaria, nan soon
# Out:
# array(['Arthropoda', nan, 'Cnidaria'], dtype=object)

# %% [markdown]
# ### Subset to US, remove NA cols, oldest records
# Doing this before further cleaning, in case any problematic rows fall under these categories.
# Arguably should have done this first, then all the checks from earlier.

# %%
# check unique country codes
df_ent_sub2.countryCode.unique()
# Out:
# array(['US', 'PE', 'BR', 'ET', 'PA', 'CM', 'CA', 'ZA', 'GB', 'CZ', 'VI',
#        'IN', 'MX', 'ES', 'PR', nan, 'PF', 'CO', 'UG', 'PH', 'LR', 'TZ',
#        'CH', 'BZ', 'RU', 'SK', 'KE', 'JP', 'GF', 'BO', 'SR', 'KR', 'ID',
#        'KN', 'PG', 'EC', 'CU', 'AR', 'TT', 'ZZ', 'HT', 'CR', 'HK', 'TH',
#        'AU', 'ZW', 'CN', 'DE', 'TW', 'GH', 'GR', 'TL', 'MY', 'FR', 'JM',
#        'MM', 'VN', 'VE', 'CD', 'GE', 'CF', 'BD', 'HU', 'VU', 'NZ', 'NI',
#        'GY', 'GT', 'CG', 'DO', 'IL', 'NG', 'SD', 'AG', 'IT', 'NP', 'TR',
#        'UA', 'LC', 'LK', 'CL', 'SB', 'GW', 'SV', 'SY', 'NC', 'PY', 'LA',
#        'AO', 'GP', 'EG', 'NO', 'SN', 'GD', 'MG', 'AS', 'KM', 'BS', 'RW',
#        'ER', 'SC', 'CY', 'MF', 'PL', 'UY', 'HN', 'VG', 'MW', 'GA', 'VC',
#        'AT', 'CI', 'ZM', 'IS', 'SG', 'FJ', 'SE', 'PT', 'IE', 'SO', 'HR',
#        'KH', 'TO', 'MT', 'SZ', 'MZ', 'BM', 'MA', 'KG', 'BW', 'AF', 'BE',
#        'LV', 'DK', 'TG', 'WS', 'KP', 'PK', 'KZ', 'MQ', 'SI', 'BA', 'UZ',
#        'SS', 'KY', 'IR', 'DM', 'BB', 'MH', 'NL', 'AL', 'RS', 'GL', 'SL',
#        'FI', 'SA', 'DZ', 'BG', 'LB', 'MU', 'PS', 'LS', 'TJ', 'ME', 'RO',
#        'TM', 'MV', 'GU', 'LU', 'MN', 'AM', 'LT', 'GN', 'BT', 'BQ', 'ML',
#        'OM', 'BI'], dtype=object)

# %%
# subset to US
df_ent_us = df_ent_sub2[df_ent_sub2.countryCode == 'US']
df_ent_us.countryCode.unique()
# Out:
# array(['US'], dtype=object)

# %%
# remove NA (or mostly NA) cols
# not making a new df for this
# coordinatePrecision, depth, depthAccuracy, establishmentMeans, recordNumber, typeStatus
# infraspecificEpithet is mostly null, but this is still useful information to keep
# because if there is a subspecies or infraspecies present, we want to know that
df_ent_us = df_ent_us.drop(columns=['coordinatePrecision', 'depth', 'depthAccuracy', 'establishmentMeans', 'recordNumber', 'typeStatus'])
df_ent_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 322008 entries, 0 to 421949
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   gbifID                            322008 non-null  int64
#  1   datasetKey                        322008 non-null  object
#  2   occurrenceID                      322008 non-null  object
#  3   kingdom                           322008 non-null  object
#  4   phylum                            321723 non-null  object
#  5   class                             321723 non-null  object
#  6   order                             321703 non-null  object
#  7   family                            321507 non-null  object
#  8   genus                             318671 non-null  object
#  9   species                           304381 non-null  object
#  10  infraspecificEpithet              3563 non-null    object
#  11  taxonRank                         322008 non-null  object
#  12  scientificName                    322008 non-null  object
#  13  verbatimScientificName            322008 non-null  object
#  14  verbatimScientificNameAuthorship  305651 non-null  object
#  15  countryCode                       322008 non-null  object
#  16  locality                          312093 non-null  object
#  17  stateProvince                     321440 non-null  object
#  18  occurrenceStatus                  322008 non-null  object
#  19  individualCount                   322008 non-null  int64
#  20  publishingOrgKey                  322008 non-null  object
#  21  decimalLatitude                   312751 non-null  float64
#  22  decimalLongitude                  312751 non-null  float64
#  23  coordinateUncertaintyInMeters     311820 non-null  float64
#  24  elevation                         33620 non-null   float64
#  25  elevationAccuracy                 1799 non-null    float64
#  26  eventDate                         302727 non-null  object
#  27  day                               279938 non-null  float64
#  28  month                             296413 non-null  float64
#  29  year                              302527 non-null  float64
#  30  taxonKey                          322008 non-null  int64
#  31  speciesKey                        304381 non-null  float64
#  32  basisOfRecord                     322008 non-null  object
#  33  institutionCode                   322008 non-null  object
#  34  collectionCode                    322008 non-null  object
#  35  catalogNumber                     322008 non-null  object
#  36  identifiedBy                      20776 non-null   object
#  37  dateIdentified                    18504 non-null   object
#  38  license                           322008 non-null  object
#  39  rightsHolder                      322008 non-null  object
#  40  recordedBy                        282054 non-null  object
#  41  lastInterpreted                   322008 non-null  object
#  42  mediaType                         16201 non-null   object
#  43  issue                             322008 non-null  object
# dtypes: float64(9), int64(3), object(32)
# memory usage: 110.6+ MB

# %%
# check format of years
# TODO: check that year is year collected not year processed where possible
df_ent_us.year.head(5)
# Out:
# 0    1966.0
# 1    1978.0
# 2    1981.0
# 3    1984.0
# 4    1960.0
# Name: year, dtype: float64

# %%
# remove records before 1900 - don't have climate data beyond that anyways
df_ent_us_recent = df_ent_us[df_ent_us.year > 1900]
df_ent_us_recent.year.head()
# Out:
# 0    1966.0
# 1    1978.0
# 2    1981.0
# 3    1984.0
# 4    1960.0
# Name: year, dtype: float64

# %%
# plot number of records per year
df_ent_us_recent.year.plot.hist()
# notice the collection bias for the 1960s-90s
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Fix Cnidaria butterflies

# %%
# check if Cnidaria is still present
df_ent_us_recent[df_ent_us_recent.phylum == 'Cnidaria']
# Out:
# Empty DataFrame
# Columns: [gbifID, datasetKey, occurrenceID, kingdom, phylum, class, order, family, genus, species, infraspecificEpithet, taxonRank, scientificName, verbatimScientificName, verbatimScientificNameAuthorship, countryCode, locality, stateProvince, occurrenceStatus, individualCount, publishingOrgKey, decimalLatitude, decimalLongitude, coordinateUncertaintyInMeters, elevation, elevationAccuracy, eventDate, day, month, year, taxonKey, speciesKey, basisOfRecord, institutionCode, collectionCode, catalogNumber, identifiedBy, dateIdentified, license, rightsHolder, recordedBy, lastInterpreted, mediaType, issue]
# Index: []
#
# [0 rows x 44 columns]

# %%
# check a different way, just in case
df_ent_us_recent.phylum.unique()

# looks like the subsets removed them, so no work needed here!
# Out:
# array(['Arthropoda', nan], dtype=object)

# %% [markdown]
# ### Fix insects with nan phyla

# %%
# check if this is still an issue
df_ent_us_recent[df_ent_us_recent.phylum.isnull()]
# still 200+ records with this issue
# Out:
#             gbifID                            datasetKey  \
# 1539    1039030291  96404cc2-f762-11e1-a439-00145eb45e9a
# 2382    2283526148  96404cc2-f762-11e1-a439-00145eb45e9a
# 3889    1039039049  96404cc2-f762-11e1-a439-00145eb45e9a
# 5404    1039044014  96404cc2-f762-11e1-a439-00145eb45e9a
# 5952    1831381367  96404cc2-f762-11e1-a439-00145eb45e9a
# ...            ...                                   ...
# 414145  1039179134  96404cc2-f762-11e1-a439-00145eb45e9a
# 415844  1039184750  96404cc2-f762-11e1-a439-00145eb45e9a
# 416421  4412912339  96404cc2-f762-11e1-a439-00145eb45e9a
# 417937  1039191601  96404cc2-f762-11e1-a439-00145eb45e9a
# 420355  1039199953  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                          occurrenceID   kingdom phylum class  \
# 1539    urn:uuid:07618e5d-319b-4109-9800-da0dccd2908b  Animalia    NaN   NaN
# 2382    urn:uuid:0b5787d0-38e7-41c7-913d-8ef3d2fba135  Animalia    NaN   NaN
# 3889    urn:uuid:12d18fbe-9e60-4973-bcaa-849e1e194cac  Animalia    NaN   NaN
# 5404    urn:uuid:1a65c7c2-09cb-4896-8d3c-6817ecc86079  Animalia    NaN   NaN
# 5952    urn:uuid:1ceecf52-a9e0-4d38-b73d-6b25a80b3850  Animalia    NaN   NaN
# ...                                               ...       ...    ...   ...
# 414145  urn:uuid:da5001e5-c52c-426a-b821-a2d51600f04f  Animalia    NaN   NaN
# 415844  urn:uuid:e2662d81-c260-48ca-9054-79b79cb91e75  Animalia    NaN   NaN
# 416421  urn:uuid:e4ff17e1-6b84-42ad-856a-eb5c0e24eaaf  Animalia    NaN   NaN
# 417937  urn:uuid:ec3b0f72-c5c1-4982-9d0d-1e2288652875  Animalia    NaN   NaN
# 420355  urn:uuid:f858014d-4b6b-4cef-9d2e-af501b1be1ef  Animalia    NaN   NaN
#
#        order      family       genus                  species  ...  \
# 1539     NaN         NaN       Caria                Caria ino  ...
# 2382     NaN  Scolytidae         NaN                      NaN  ...
# 3889     NaN         NaN  Calephelis       Calephelis nemesis  ...
# 5404     NaN         NaN  Calephelis      Calephelis borealis  ...
# 5952     NaN         NaN  Calephelis      Calephelis borealis  ...
# ...      ...         ...         ...                      ...  ...
# 414145   NaN         NaN  Calephelis  Calephelis virginiensis  ...
# 415844   NaN         NaN  Calephelis       Calephelis nemesis  ...
# 416421   NaN         NaN  Calephelis      Calephelis borealis  ...
# 417937   NaN         NaN  Calephelis  Calephelis virginiensis  ...
# 420355   NaN         NaN       Caria                Caria ino  ...
#
#        collectionCode   catalogNumber identifiedBy dateIdentified  license  \
# 1539              ENT  YPM ENT 756892          NaN            NaN  CC0_1_0
# 2382              ENT  YPM ENT 969752          NaN            NaN  CC0_1_0
# 3889              ENT  YPM ENT 443283          NaN            NaN  CC0_1_0
# 5404              ENT  YPM ENT 755959          NaN            NaN  CC0_1_0
# 5952              ENT  YPM ENT 934340          NaN            NaN  CC0_1_0
# ...               ...             ...          ...            ...      ...
# 414145            ENT  YPM ENT 796568          NaN            NaN  CC0_1_0
# 415844            ENT  YPM ENT 755041          NaN            NaN  CC0_1_0
# 416421            ENT  YPM ENT 601117          NaN            NaN  CC0_1_0
# 417937            ENT  YPM ENT 443262          NaN            NaN  CC0_1_0
# 420355            ENT  YPM ENT 756890          NaN            NaN  CC0_1_0
#
#                rightsHolder                         recordedBy  \
# 1539    Yale Peabody Museum                   John R. Heitzman
# 2382    Yale Peabody Museum                 Raymond J. Pupedis
# 3889    Yale Peabody Museum                     Roy O. Kendall
# 5404    Yale Peabody Museum                                NaN
# 5952    Yale Peabody Museum  Thomas Breden, Dale F. Schweitzer
# ...                     ...                                ...
# 414145  Yale Peabody Museum                  Victoria J. Mason
# 415844  Yale Peabody Museum                  Roger L. Heitzman
# 416421  Yale Peabody Museum                    John W. Peacock
# 417937  Yale Peabody Museum                      Dean F. Berry
# 420355  Yale Peabody Museum                  Herman P. Wilhelm
#
#                  lastInterpreted mediaType  \
# 1539    2025-04-01T13:31:37.201Z       NaN
# 2382    2025-04-01T13:31:38.364Z       NaN
# 3889    2025-04-01T13:31:37.956Z       NaN
# 5404    2025-04-01T13:31:42.566Z       NaN
# 5952    2025-04-01T13:31:43.162Z       NaN
# ...                          ...       ...
# 414145  2025-04-01T13:32:12.125Z       NaN
# 415844  2025-04-01T13:32:13.008Z       NaN
# 416421  2025-04-01T13:32:13.168Z       NaN
# 417937  2025-04-01T13:32:14.565Z       NaN
# 420355  2025-04-01T13:32:16.013Z       NaN
#
#                                                     issue
# 1539    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 2382    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 3889    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 5404    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 5952    OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# ...                                                   ...
# 414145  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 415844  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 416421  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 417937  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 420355  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [262 rows x 44 columns]

# %%
# find out which unique species/genera/families are represented here
df_ent_us_recent[df_ent_us_recent.phylum.isnull()].species.unique()
# Out:
# array(['Caria ino', nan, 'Calephelis nemesis', 'Calephelis borealis',
#        'Calephelis virginiensis'], dtype=object)

# %%
df_ent_us_recent[df_ent_us_recent.phylum.isnull()].genus.unique()
# Out:
# array(['Caria', nan, 'Calephelis', 'Brachybothrium'], dtype=object)

# %%
# check families
df_ent_us_recent[df_ent_us_recent.phylum.isnull()].family.unique()
# none
# Out:
# array([nan, 'Scolytidae'], dtype=object)

# %%
# check orders
df_ent_us_recent[df_ent_us_recent.phylum.isnull()].order.unique()
# none
# Out:
# array([nan], dtype=object)

# %% [markdown]
# Will need to add in genus, family, order, class, phylum for the unmatched taxa
# * species: 'Caria ino', 'Calephelis nemesis', 'Calephelis borealis', 'Calephelis virginiensis'
# * genus: 'Caria', 'Calephelis', 'Brachybothrium'
# * family: 'Scolytidae'
#
# It may be that all genera are present if species is present, so fix genus and family then check if any species were left behind.
#
# We will pull the correct taxonomy from GBIF or Wikipedia
#
# At the end, check if there any NA rows remaining

# %%
# Is the taxonomy correct for other instances of these taxa?
df_ent_us_recent[df_ent_us_recent.family == 'Scolytidae'].order.unique()
# nope
# Out:
# array([nan], dtype=object)

# %%
# start with family, since there's only one to fix
# Arthropoda - Insecta - Coleoptera - Scolytidae
df_ent_us_recent.loc[df_ent_us_recent.family == 'Scolytidae', ['phylum', 'class', 'order']] = 'Arthropoda', 'Insecta', 'Coleoptera'

df_ent_us_recent[df_ent_us_recent.family == 'Scolytidae'].head() # check
# Out:
#            gbifID                            datasetKey  \
# 2382   2283526148  96404cc2-f762-11e1-a439-00145eb45e9a
# 10895  2283526464  96404cc2-f762-11e1-a439-00145eb45e9a
# 30768  2283527095  96404cc2-f762-11e1-a439-00145eb45e9a
# 34638  2283530209  96404cc2-f762-11e1-a439-00145eb45e9a
# 41036  2283532388  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                         occurrenceID   kingdom      phylum  \
# 2382   urn:uuid:0b5787d0-38e7-41c7-913d-8ef3d2fba135  Animalia  Arthropoda
# 10895  urn:uuid:3478f083-b1cc-45ea-b2d3-28279b960c04  Animalia  Arthropoda
# 30768  urn:uuid:95c4f470-6378-4b8a-8c3a-3a0640c696f8  Animalia  Arthropoda
# 34638  urn:uuid:a8730d63-5e34-4854-8a0d-a0345cd06d30  Animalia  Arthropoda
# 41036  urn:uuid:c79a31fd-ed6f-42bf-8ec5-b75bd73529e1  Animalia  Arthropoda
#
#          class       order      family genus species  ... collectionCode  \
# 2382   Insecta  Coleoptera  Scolytidae   NaN     NaN  ...            ENT
# 10895  Insecta  Coleoptera  Scolytidae   NaN     NaN  ...            ENT
# 30768  Insecta  Coleoptera  Scolytidae   NaN     NaN  ...            ENT
# 34638  Insecta  Coleoptera  Scolytidae   NaN     NaN  ...            ENT
# 41036  Insecta  Coleoptera  Scolytidae   NaN     NaN  ...            ENT
#
#         catalogNumber identifiedBy dateIdentified  license  \
# 2382   YPM ENT 969752          NaN            NaN  CC0_1_0
# 10895  YPM ENT 969497          NaN            NaN  CC0_1_0
# 30768  YPM ENT 969506          NaN            NaN  CC0_1_0
# 34638  YPM ENT 969504          NaN            NaN  CC0_1_0
# 41036  YPM ENT 969503          NaN            NaN  CC0_1_0
#
#               rightsHolder          recordedBy           lastInterpreted  \
# 2382   Yale Peabody Museum  Raymond J. Pupedis  2025-04-01T13:31:38.364Z
# 10895  Yale Peabody Museum  Raymond J. Pupedis  2025-04-01T13:31:47.719Z
# 30768  Yale Peabody Museum  Raymond J. Pupedis  2025-04-01T13:32:04.302Z
# 34638  Yale Peabody Museum  Raymond J. Pupedis  2025-04-01T13:32:05.934Z
# 41036  Yale Peabody Museum  Raymond J. Pupedis  2025-04-01T13:32:10.215Z
#
#       mediaType                                              issue
# 2382        NaN  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 10895       NaN  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 30768       NaN  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 34638       NaN  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 41036       NaN  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [5 rows x 44 columns]

# %% [markdown]
# Calephelis - Riodinidae - Lepidoptera - Insecta - Arthropoda
#
# Caria - Riodinidae - Lepidoptera - Insecta - Arthropoda
#
# Brachybothrium - Antrodiaetidae - Arachnida - Chelicerata - Arthropoda
# * however, there are only 2 records on all of GBIF (not just YPM), so it is likely an unused synonym
# * removing this record since it is uncertain

# %%
# is the taxonomy correct in other instances of the genera?
df_ent_us_recent[df_ent_us_recent.genus.isin(['Caria', 'Calephelis', 'Brachybothrium'])].order.unique()
# nope
# Out:
# array([nan], dtype=object)

# %%
# apply correction the same as above
df_ent_us_recent.loc[df_ent_us_recent.genus.isin(['Caria', 'Calephelis']), ['phylum', 'class', 'order', 'family']] = 'Arthropoda', 'Insecta', 'Lepidoptera', 'Riodinidae'

df_ent_us_recent[df_ent_us_recent.genus.isin(['Caria', 'Calephelis'])].head() # check
# Out:
#           gbifID                            datasetKey  \
# 1539  1039030291  96404cc2-f762-11e1-a439-00145eb45e9a
# 3889  1039039049  96404cc2-f762-11e1-a439-00145eb45e9a
# 5404  1039044014  96404cc2-f762-11e1-a439-00145eb45e9a
# 5952  1831381367  96404cc2-f762-11e1-a439-00145eb45e9a
# 6660  1831381283  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                        occurrenceID   kingdom      phylum  \
# 1539  urn:uuid:07618e5d-319b-4109-9800-da0dccd2908b  Animalia  Arthropoda
# 3889  urn:uuid:12d18fbe-9e60-4973-bcaa-849e1e194cac  Animalia  Arthropoda
# 5404  urn:uuid:1a65c7c2-09cb-4896-8d3c-6817ecc86079  Animalia  Arthropoda
# 5952  urn:uuid:1ceecf52-a9e0-4d38-b73d-6b25a80b3850  Animalia  Arthropoda
# 6660  urn:uuid:206034a8-85e1-441b-bb08-38bcad8b3383  Animalia  Arthropoda
#
#         class        order      family       genus              species  ...  \
# 1539  Insecta  Lepidoptera  Riodinidae       Caria            Caria ino  ...
# 3889  Insecta  Lepidoptera  Riodinidae  Calephelis   Calephelis nemesis  ...
# 5404  Insecta  Lepidoptera  Riodinidae  Calephelis  Calephelis borealis  ...
# 5952  Insecta  Lepidoptera  Riodinidae  Calephelis  Calephelis borealis  ...
# 6660  Insecta  Lepidoptera  Riodinidae  Calephelis  Calephelis borealis  ...
#
#      collectionCode   catalogNumber identifiedBy dateIdentified  license  \
# 1539            ENT  YPM ENT 756892          NaN            NaN  CC0_1_0
# 3889            ENT  YPM ENT 443283          NaN            NaN  CC0_1_0
# 5404            ENT  YPM ENT 755959          NaN            NaN  CC0_1_0
# 5952            ENT  YPM ENT 934340          NaN            NaN  CC0_1_0
# 6660            ENT  YPM ENT 934338          NaN            NaN  CC0_1_0
#
#              rightsHolder                         recordedBy  \
# 1539  Yale Peabody Museum                   John R. Heitzman
# 3889  Yale Peabody Museum                     Roy O. Kendall
# 5404  Yale Peabody Museum                                NaN
# 5952  Yale Peabody Museum  Thomas Breden, Dale F. Schweitzer
# 6660  Yale Peabody Museum  Thomas Breden, Dale F. Schweitzer
#
#                lastInterpreted mediaType  \
# 1539  2025-04-01T13:31:37.201Z       NaN
# 3889  2025-04-01T13:31:37.956Z       NaN
# 5404  2025-04-01T13:31:42.566Z       NaN
# 5952  2025-04-01T13:31:43.162Z       NaN
# 6660  2025-04-01T13:31:43.820Z       NaN
#
#                                                   issue
# 1539  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 3889  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 5404  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 5952  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 6660  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [5 rows x 44 columns]

# %%
# remove record with Brachybothrium
df_ent_us_recent = df_ent_us_recent[df_ent_us_recent.genus != 'Brachybothrium']

df_ent_us_recent[df_ent_us_recent.genus == 'Brachybothrium']
# Out:
# Empty DataFrame
# Columns: [gbifID, datasetKey, occurrenceID, kingdom, phylum, class, order, family, genus, species, infraspecificEpithet, taxonRank, scientificName, verbatimScientificName, verbatimScientificNameAuthorship, countryCode, locality, stateProvince, occurrenceStatus, individualCount, publishingOrgKey, decimalLatitude, decimalLongitude, coordinateUncertaintyInMeters, elevation, elevationAccuracy, eventDate, day, month, year, taxonKey, speciesKey, basisOfRecord, institutionCode, collectionCode, catalogNumber, identifiedBy, dateIdentified, license, rightsHolder, recordedBy, lastInterpreted, mediaType, issue]
# Index: []
#
# [0 rows x 44 columns]

# %%
# check that fixing genera also fixed species
df_ent_us_recent[df_ent_us_recent.phylum.isnull()].species.unique() # looks good
# Out:
# array([], dtype=object)

# %% [markdown]
# ### Fix year type

# %%
# year has a decimal place, fix that
df_ent_us_recent.year = df_ent_us_recent.year.astype('int')

print(df_ent_us_recent.year.dtype)
df_ent_us_recent.year.head(2)
# Out:
# int64
# 0    1966
# 1    1978
# Name: year, dtype: int64

# %% [markdown]
# ## Save dataset

# %%
# saved cleaned table
df_ent_us_recent.to_csv('ypm_ent_usa_post1900_cleaned_20250408.csv', index=False)

# %% [markdown]
# # Calculate summary table

# %% [markdown]
# ## Create summary table
# Goal: make a table with a column for:
# *   year
# *   state
# *   total number of species
# *   total abundance (number of occurrences)
# *   Lepidoptera n species
# *   Lepidoptera abundance
# *   Hymenoptera n species and abundance
# *   Diptera n species and abundance
# *   Coleoptera n species and abundance
# *   Odonata n species and abundance
# *   Nymphalidae n species and abundance
#
# Note that inferring abundance from museum records is quite biased - would not normally do this without applying some mathematical corrections, but for now are leaving as is for the purposes of exploring. We will likely only analyze number of species, not number of occurrences (abundance).

# %%
# read in cleaned table if needed
ypm_ent = pd.read_csv('ypm_ent_usa_post1900_cleaned_20250408.csv') # uploaded this to my runtime files temporarily, too big to load to github

ypm_ent.head()
# Out:
#        gbifID                            datasetKey  \
# 0  3913895301  96404cc2-f762-11e1-a439-00145eb45e9a
# 1  1438048515  96404cc2-f762-11e1-a439-00145eb45e9a
# 2  1838432720  96404cc2-f762-11e1-a439-00145eb45e9a
# 3  1935872503  96404cc2-f762-11e1-a439-00145eb45e9a
# 4  2565549387  96404cc2-f762-11e1-a439-00145eb45e9a
#
#                                     occurrenceID   kingdom      phylum  \
# 0  urn:uuid:00006775-753e-4ed0-bbe6-0702cae6c26b  Animalia  Arthropoda
# 1  urn:uuid:000426c2-4fff-44bf-97c3-461d8022c177  Animalia  Arthropoda
# 2  urn:uuid:00091984-cf96-4498-a6c6-e034f72a355a  Animalia  Arthropoda
# 3  urn:uuid:0009a4ea-0d53-46da-bf70-949145977b1b  Animalia  Arthropoda
# 4  urn:uuid:000a73bd-10b3-46d3-b38c-be8c3d909b83  Animalia  Arthropoda
#
#      class        order        family         genus                  species  \
# 0  Insecta  Lepidoptera  Papilionidae       Papilio        Papilio polyxenes
# 1  Insecta  Lepidoptera     Noctuidae       Achatia           Achatia evicta
# 2  Insecta  Lepidoptera   Geometridae     Lobophora     Lobophora nivigerata
# 3  Insecta  Lepidoptera   Geometridae  Metarranthis  Metarranthis amyrisaria
# 4  Insecta  Lepidoptera     Crambidae     Parapoynx     Parapoynx obscuralis
#
#    ... collectionCode   catalogNumber identifiedBy dateIdentified  license  \
# 0  ...            ENT  YPM ENT 592844          NaN            NaN  CC0_1_0
# 1  ...            ENT  YPM ENT 882660          NaN            NaN  CC0_1_0
# 2  ...            ENT  YPM ENT 941874          NaN            NaN  CC0_1_0
# 3  ...            ENT  YPM ENT 956749          NaN            NaN  CC0_1_0
# 4  ...            ENT  YPM ENT 986749          NaN            NaN  CC0_1_0
#
#           rightsHolder                             recordedBy  \
# 0  Yale Peabody Museum                             R. T. Cail
# 1  Yale Peabody Museum                        Richard E. Gray
# 2  Yale Peabody Museum                     David S. MacDonald
# 3  Yale Peabody Museum  Timothy L. McCabe, Dale F. Schweitzer
# 4  Yale Peabody Museum                      Herman P. Wilhelm
#
#             lastInterpreted mediaType  \
# 0  2025-04-01T13:31:34.353Z       NaN
# 1  2025-04-01T13:31:34.410Z       NaN
# 2  2025-04-01T13:31:25.822Z       NaN
# 3  2025-04-01T13:31:34.328Z       NaN
# 4  2025-04-01T13:31:34.426Z       NaN
#
#                                                issue
# 0  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 1  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 2  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 3  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
# 4  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COU...
#
# [5 rows x 44 columns]

# %%
ypm_ent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300109 entries, 0 to 300108
# Data columns (total 44 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   gbifID                            300109 non-null  int64
#  1   datasetKey                        300109 non-null  object
#  2   occurrenceID                      300109 non-null  object
#  3   kingdom                           300109 non-null  object
#  4   phylum                            300109 non-null  object
#  5   class                             300109 non-null  object
#  6   order                             300091 non-null  object
#  7   family                            299864 non-null  object
#  8   genus                             297026 non-null  object
#  9   species                           284483 non-null  object
#  10  infraspecificEpithet              3328 non-null    object
#  11  taxonRank                         300109 non-null  object
#  12  scientificName                    300109 non-null  object
#  13  verbatimScientificName            300109 non-null  object
#  14  verbatimScientificNameAuthorship  285659 non-null  object
#  15  countryCode                       300109 non-null  object
#  16  locality                          294092 non-null  object
#  17  stateProvince                     299748 non-null  object
#  18  occurrenceStatus                  300109 non-null  object
#  19  individualCount                   300109 non-null  int64
#  20  publishingOrgKey                  300109 non-null  object
#  21  decimalLatitude                   292076 non-null  float64
#  22  decimalLongitude                  292076 non-null  float64
#  23  coordinateUncertaintyInMeters     291198 non-null  float64
#  24  elevation                         32750 non-null   float64
#  25  elevationAccuracy                 1753 non-null    float64
#  26  eventDate                         300109 non-null  object
#  27  day                               278147 non-null  float64
#  28  month                             294344 non-null  float64
#  29  year                              300109 non-null  float64
#  30  taxonKey                          300109 non-null  int64
#  31  speciesKey                        284483 non-null  float64
#  32  basisOfRecord                     300109 non-null  object
#  33  institutionCode                   300109 non-null  object
#  34  collectionCode                    300109 non-null  object
#  35  catalogNumber                     300109 non-null  object
#  36  identifiedBy                      20059 non-null   object
#  37  dateIdentified                    17882 non-null   object
#  38  license                           300109 non-null  object
#  39  rightsHolder                      300109 non-null  object
#  40  recordedBy                        268753 non-null  object
#  41  lastInterpreted                   300109 non-null  object
#  42  mediaType                         15323 non-null   object
#  43  issue                             300109 non-null  object
# dtypes: float64(9), int64(3), object(32)
# memory usage: 100.7+ MB

# %%
# aggregate and calculate cols for total n species and abundance
ent_totals = ypm_ent.groupby(['year', 'stateProvince']).agg(total_n_species = ('verbatimScientificName', 'nunique'),
                                               total_abundance = ('verbatimScientificName', 'count')).reset_index()
ent_totals.tail()
# Out:
#       year  stateProvince  total_richness  total_abundance
# 4170  2024        Florida              29               56
# 4171  2024          Maine               3                3
# 4172  2024       Maryland               2                3
# 4173  2024  New Hampshire              40              121
# 4174  2024       Virginia               3               10

# %%
# calculate cols for lepidoptera rich and abund - won't need this
ent_lepid = ypm_ent[ypm_ent.order == 'Lepidoptera'].groupby(['year', 'stateProvince']).agg(lepidoptera_n_species = ('verbatimScientificName', 'nunique'),
                                               lepidoptera_abundance = ('verbatimScientificName', 'count')).reset_index()
ent_lepid.tail()
# Out:
#       year  stateProvince  lepidoptera_richness  lepidoptera_abundance
# 3867  2024    Connecticut                     5                     11
# 3868  2024        Florida                    29                     56
# 3869  2024          Maine                     3                      3
# 3870  2024  New Hampshire                    40                    121
# 3871  2024       Virginia                     3                     10

# %%
# do this as a loop?

orders = ypm_ent.order.unique()

for i in orders:
  print(i)
  df_tmp = ypm_ent[ypm_ent.order == i].groupby(['year', 'stateProvince']).agg(
    richness = ('verbatimScientificName', 'nunique'),
    abundance = ('verbatimScientificName', 'count')
    ).reset_index()
  df_tmp = df_tmp.rename(columns = {'n_species': f'{i}_richness', 'abundance': f'{i}_abundance'})
  ent_totals = ent_totals.merge(df_tmp, how='outer', on=['year','stateProvince'])

ent_totals.tail()
# Out:
# Lepidoptera
# Hymenoptera
# Coleoptera
# Diptera
# Odonata
# Ixodida
# Megaloptera
# Hemiptera
# Orthoptera
# Trichoptera
# Trombidiformes
# Neuroptera
# Psocodea
# Mesostigmata
# Siphonaptera
# Mecoptera
# nan
# Sarcoptiformes
# Araneae
# Thysanoptera
# Entomobryomorpha
# Raphidioptera
# Mantodea
# Scolopendromorpha
# Ephemeroptera
# Scorpiones
# Solifugae
# Dermaptera
# Spirobolida
# Pseudoscorpiones
# Poduromorpha
#       year  stateProvince  total_richness  total_abundance  \
# 4170  2024        Florida              29               56
# 4171  2024          Maine               3                3
# 4172  2024       Maryland               2                3
# 4173  2024  New Hampshire              40              121
# 4174  2024       Virginia               3               10
#
#       Lepidoptera_richness  Lepidoptera_abundance  Hymenoptera_richness  \
# 4170                  29.0                   56.0                   NaN
# 4171                   3.0                    3.0                   NaN
# 4172                   NaN                    NaN                   NaN
# 4173                  40.0                  121.0                   NaN
# 4174                   3.0                   10.0                   NaN
#
#       Hymenoptera_abundance  Coleoptera_richness  Coleoptera_abundance  ...  \
# 4170                    NaN                  NaN                   NaN  ...
# 4171                    NaN                  NaN                   NaN  ...
# 4172                    NaN                  NaN                   NaN  ...
# 4173                    NaN                  NaN                   NaN  ...
# 4174                    NaN                  NaN                   NaN  ...
#
#       Solifugae_richness  Solifugae_abundance  Dermaptera_richness  \
# 4170                 NaN                  NaN                  NaN
# 4171                 NaN                  NaN                  NaN
# 4172                 NaN                  NaN                  NaN
# 4173                 NaN                  NaN                  NaN
# 4174                 NaN                  NaN                  NaN
#
#       Dermaptera_abundance  Spirobolida_richness  Spirobolida_abundance  \
# 4170                   NaN                   NaN                    NaN
# 4171                   NaN                   NaN                    NaN
# 4172                   NaN                   NaN                    NaN
# 4173                   NaN                   NaN                    NaN
# 4174                   NaN                   NaN                    NaN
#
#       Pseudoscorpiones_richness  Pseudoscorpiones_abundance  \
# 4170                        NaN                         NaN
# 4171                        NaN                         NaN
# 4172                        NaN                         NaN
# 4173                        NaN                         NaN
# 4174                        NaN                         NaN
#
#       Poduromorpha_richness  Poduromorpha_abundance
# 4170                    NaN                     NaN
# 4171                    NaN                     NaN
# 4172                    NaN                     NaN
# 4173                    NaN                     NaN
# 4174                    NaN                     NaN
#
# [5 rows x 66 columns]

# %%
# now do it for the families of interest

families = ['Nymphalidae', 'Apidae', 'Noctuidae', 'Papilionidae'] # some common, some important

for i in families:
  print(i)
  df_tmp = ypm_ent[ypm_ent.family == i].groupby(['year', 'stateProvince']).agg(
    richness = ('verbatimScientificName', 'nunique'),
    abundance = ('verbatimScientificName', 'count')
    ).reset_index()
  df_tmp = df_tmp.rename(columns = {'n_species': f'{i}_richness', 'abundance': f'{i}_abundance'})
  ent_totals = ent_totals.merge(df_tmp, how='outer', on=['year','stateProvince'])

ent_totals.tail()
# Out:
# Nymphalidae
# Apidae
# Noctuidae
# Papilionidae
#       year  stateProvince  total_richness  total_abundance  \
# 4170  2024        Florida              29               56
# 4171  2024          Maine               3                3
# 4172  2024       Maryland               2                3
# 4173  2024  New Hampshire              40              121
# 4174  2024       Virginia               3               10
#
#       Lepidoptera_richness  Lepidoptera_abundance  Hymenoptera_richness  \
# 4170                  29.0                   56.0                   NaN
# 4171                   3.0                    3.0                   NaN
# 4172                   NaN                    NaN                   NaN
# 4173                  40.0                  121.0                   NaN
# 4174                   3.0                   10.0                   NaN
#
#       Hymenoptera_abundance  Coleoptera_richness  Coleoptera_abundance  ...  \
# 4170                    NaN                  NaN                   NaN  ...
# 4171                    NaN                  NaN                   NaN  ...
# 4172                    NaN                  NaN                   NaN  ...
# 4173                    NaN                  NaN                   NaN  ...
# 4174                    NaN                  NaN                   NaN  ...
#
#       Poduromorpha_richness  Poduromorpha_abundance  Nymphalidae_richness  \
# 4170                    NaN                     NaN                   NaN
# 4171                    NaN                     NaN                   NaN
# 4172                    NaN                     NaN                   NaN
# 4173                    NaN                     NaN                   NaN
# 4174                    NaN                     NaN                   NaN
#
#       Nymphalidae_abundance  Apidae_richness  Apidae_abundance  \
# 4170                    NaN              NaN               NaN
# 4171                    NaN              NaN               NaN
# 4172                    NaN              NaN               NaN
# 4173                    NaN              NaN               NaN
# 4174                    NaN              NaN               NaN
#
#       Noctuidae_richness  Noctuidae_abundance  Papilionidae_richness  \
# 4170                 NaN                  NaN                    NaN
# 4171                 NaN                  NaN                    NaN
# 4172                 NaN                  NaN                    NaN
# 4173                 NaN                  NaN                    NaN
# 4174                 NaN                  NaN                    NaN
#
#       Papilionidae_abundance
# 4170                     NaN
# 4171                     NaN
# 4172                     NaN
# 4173                     NaN
# 4174                     NaN
#
# [5 rows x 74 columns]

# %% [markdown]
# ## Save dataset

# %%
# save this version
ent_totals.to_csv('ypm_ent_taxo_summaries_20250408.csv', index=False)
# TODO: end this notebook here and make a new one for analysis

# %% [markdown]
# # Final project needs

# %% [markdown]
# ## Subset dataset to CT only and the most interesting orders for joining to climate data

# %%
# read in data
ent = pd.read_csv('ypm_ent_taxo_summaries_20250408.csv')
ent.head()
# Out:
#    year stateProvince  total_richness  total_abundance  Lepidoptera_richness  \
# 0  1901        Alaska               1                1                   1.0
# 1  1901       Arizona               1                1                   1.0
# 2  1901    California               4                6                   1.0
# 3  1901      Colorado               2                3                   1.0
# 4  1901   Connecticut               7                7                   6.0
#
#    Lepidoptera_abundance  Hymenoptera_richness  Hymenoptera_abundance  \
# 0                    1.0                   NaN                    NaN
# 1                    1.0                   NaN                    NaN
# 2                    2.0                   NaN                    NaN
# 3                    1.0                   NaN                    NaN
# 4                    6.0                   NaN                    NaN
#
#    Coleoptera_richness  Coleoptera_abundance  ...  Poduromorpha_richness  \
# 0                  NaN                   NaN  ...                    NaN
# 1                  NaN                   NaN  ...                    NaN
# 2                  3.0                   4.0  ...                    NaN
# 3                  1.0                   2.0  ...                    NaN
# 4                  1.0                   1.0  ...                    NaN
#
#    Poduromorpha_abundance  Nymphalidae_richness  Nymphalidae_abundance  \
# 0                     NaN                   NaN                    NaN
# 1                     NaN                   NaN                    NaN
# 2                     NaN                   NaN                    NaN
# 3                     NaN                   1.0                    1.0
# 4                     NaN                   NaN                    NaN
#
#    Apidae_richness  Apidae_abundance  Noctuidae_richness  Noctuidae_abundance  \
# 0              NaN               NaN                 NaN                  NaN
# 1              NaN               NaN                 NaN                  NaN
# 2              NaN               NaN                 NaN                  NaN
# 3              NaN               NaN                 NaN                  NaN
# 4              NaN               NaN                 NaN                  NaN
#
#    Papilionidae_richness  Papilionidae_abundance
# 0                    NaN                     NaN
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
#
# [5 rows x 74 columns]

# %%
# subset to CT
ent_ct = ent[ent.stateProvince == 'Connecticut']
ent_ct.value_counts('stateProvince') # good
# Out:
# stateProvince
# Connecticut    124
# Name: count, dtype: int64

# %%
# select just a few orders of interest
ent_ct_sub = ent_ct[['year', 'stateProvince', 'total_richness', 'Nymphalidae_richness', 'Apidae_richness', 'Noctuidae_richness', 'Lepidoptera_richness', 'Papilionidae_richness', 'Coleoptera_richness']]
ent_ct_sub.head()
# Out:
#     year stateProvince  total_richness  Nymphalidae_richness  Apidae_richness  \
# 4   1901   Connecticut               7                   NaN              NaN
# 30  1902   Connecticut               7                   NaN              1.0
# 53  1903   Connecticut               9                   NaN              NaN
# 74  1904   Connecticut              45                   NaN              5.0
# 99  1905   Connecticut              30                   NaN              5.0
#
#     Noctuidae_richness  Lepidoptera_richness  Papilionidae_richness  \
# 4                  NaN                   6.0                    NaN
# 30                 NaN                   1.0                    1.0
# 53                 NaN                   5.0                    NaN
# 74                 NaN                   4.0                    NaN
# 99                 NaN                   8.0                    NaN
#
#     Coleoptera_richness
# 4                   1.0
# 30                  1.0
# 53                  NaN
# 74                  NaN
# 99                  1.0

# %%
# save subsetted file
ent_ct_sub.to_csv('ypm_ct_ent_taxo_summaries_20250418.csv', index=False)

# %% [markdown]
# ## Merge datasets
# Merge temp, precip, and insect datasets for CT

# %% [markdown]
# ### Read in datasets

# %%
# read in precip data
df_pr = pd.read_csv('noaa_precip_yearly_ct.csv')
df_pr.head()
# Out:
#    DATE   PAVG   PMIN   PMAX
# 0  1858  41.89  41.89  41.89
# 1  1859  53.31  53.31  53.31
# 2  1860  37.38  37.38  37.38
# 3  1861  47.03  47.03  47.03
# 4  1862  48.02  48.02  48.02

# %%
# read in temp data
df_t = pd.read_csv('noaa_temp_yearly_ct.csv')
df_t.head()
# Out:
#    DATE       TMIN       TAVG       TMAX
# 0  2000  39.730769  49.566667  59.425000
# 1  2001  40.709091  51.254545  61.800000
# 2  2002  41.791667  51.808333  61.646154
# 3  2003  39.715385  48.976923  58.230769
# 4  2004  39.923077  49.700000  59.184615

# %%
# read in CT ent data
df_e = pd.read_csv('ypm_ct_ent_taxo_summaries_20250418.csv')
df_e.head()
# Out:
#    year stateProvince  total_richness  Nymphalidae_richness  Apidae_richness  \
# 0  1901   Connecticut               7                   NaN              NaN
# 1  1902   Connecticut               7                   NaN              1.0
# 2  1903   Connecticut               9                   NaN              NaN
# 3  1904   Connecticut              45                   NaN              5.0
# 4  1905   Connecticut              30                   NaN              5.0
#
#    Noctuidae_richness  Lepidoptera_richness  Papilionidae_richness  \
# 0                 NaN                   6.0                    NaN
# 1                 NaN                   1.0                    1.0
# 2                 NaN                   5.0                    NaN
# 3                 NaN                   4.0                    NaN
# 4                 NaN                   8.0                    NaN
#
#    Coleoptera_richness
# 0                  1.0
# 1                  1.0
# 2                  NaN
# 3                  NaN
# 4                  1.0

# %%
df_e.rename(columns={'year': 'DATE'}, inplace=True)
df_e.head()
# Out:
#    DATE stateProvince  total_richness  Nymphalidae_richness  Apidae_richness  \
# 0  1901   Connecticut               7                   NaN              NaN
# 1  1902   Connecticut               7                   NaN              1.0
# 2  1903   Connecticut               9                   NaN              NaN
# 3  1904   Connecticut              45                   NaN              5.0
# 4  1905   Connecticut              30                   NaN              5.0
#
#    Noctuidae_richness  Lepidoptera_richness  Papilionidae_richness  \
# 0                 NaN                   6.0                    NaN
# 1                 NaN                   1.0                    1.0
# 2                 NaN                   5.0                    NaN
# 3                 NaN                   4.0                    NaN
# 4                 NaN                   8.0                    NaN
#
#    Coleoptera_richness
# 0                  1.0
# 1                  1.0
# 2                  NaN
# 3                  NaN
# 4                  1.0

# %% [markdown]
# ### Merge

# %%
# merge temp and precip
df_tp = df_t.merge(df_pr,how='outer', on='DATE')
df_tp.tail()
# Out:
#      DATE       TMIN       TAVG       TMAX       PAVG   PMIN   PMAX
# 162  2021  42.278571  51.507143  60.721429  53.334416  38.43  66.84
# 163  2022  40.656250  50.962500  61.305882  46.398205  34.26  57.14
# 164  2023  42.686667  52.173333  61.660000  62.344521  46.20  73.91
# 165  2024  42.162500  51.956250  61.762500  54.480676  41.60  66.27
# 166  2025        NaN        NaN        NaN        NaN    NaN    NaN

# %%
# merge ent data on to climate data
df_all = df_tp.merge(df_e,how='inner', on='DATE')
df_all.head()
# Out:
#    DATE  TMIN  TAVG  TMAX       PAVG   PMIN   PMAX stateProvince  \
# 0  1901   NaN   NaN   NaN  59.651111  38.67  68.77   Connecticut
# 1  1902   NaN   NaN   NaN  52.378571  34.96  61.85   Connecticut
# 2  1903   NaN   NaN   NaN  49.262857  34.44  58.02   Connecticut
# 3  1904   NaN   NaN   NaN  43.526250  38.05  48.22   Connecticut
# 4  1905   NaN   NaN   NaN  41.735714  36.13  52.78   Connecticut
#
#    total_richness  Nymphalidae_richness  Apidae_richness  Noctuidae_richness  \
# 0               7                   NaN              NaN                 NaN
# 1               7                   NaN              1.0                 NaN
# 2               9                   NaN              NaN                 NaN
# 3              45                   NaN              5.0                 NaN
# 4              30                   NaN              5.0                 NaN
#
#    Lepidoptera_richness  Papilionidae_richness  Coleoptera_richness
# 0                   6.0                    NaN                  1.0
# 1                   1.0                    1.0                  1.0
# 2                   5.0                    NaN                  NaN
# 3                   4.0                    NaN                  NaN
# 4                   8.0                    NaN                  1.0

# %%
df_all.to_csv('CT_insect_climate_data.csv', index=False)

# %%
# TODO: make some visualizations, summary stats before doing regressions

# %%
# want temp/precip NAs to stay NA, but insect NAs should be 0? maybe

# %% [markdown]
# ## Run linear regressions on data
# Will try all possible combinations - write as a loop?

# %%
# first a simple one
model = sm.OLS(df_all.PMAX,df_all.total_richness)
result = model.fit()
result.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                         Results: Ordinary least squares
# ===============================================================================
# Model:                  OLS              Adj. R-squared (uncentered): 0.592
# Dependent Variable:     PMAX             AIC:                         1244.1246
# Date:                   2025-04-21 17:26 BIC:                         1246.9449
# No. Observations:       124              Log-Likelihood:              -621.06
# Df Model:               1                F-statistic:                 180.6
# Df Residuals:           123              Prob (F-statistic):          6.78e-26
# R-squared (uncentered): 0.595            Scale:                       1322.6
# -----------------------------------------------------------------------------------
#                    Coef.      Std.Err.        t        P>|t|      [0.025     0.975]
# -----------------------------------------------------------------------------------
# total_richness     0.2051       0.0153     13.4400     0.0000     0.1749     0.2353
# -------------------------------------------------------------------------------
# Omnibus:                   8.674             Durbin-Watson:               0.370
# Prob(Omnibus):             0.013             Jarque-Bera (JB):            9.286
# Skew:                      -0.658            Prob(JB):                    0.010
# Kurtosis:                  2.740             Condition No.:               1
# ===============================================================================
# Notes:
# [1] R² is computed without centering (uncentered) since the
# model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# """

# %%
df_all.plot('PMAX', 'total_richness') # this looks bad!
# Out:
# <Axes: xlabel='PMAX'>

# %%
# loop through climate and response vars and run regressions

# %%
# prompt: loop through columns 2:7 as independent variables and 9:15 as dependent vars and run linear regressions for each combination of variables, saving the p and R2 values from each regression in a dataframe

import pandas as pd
import statsmodels.api as sm

# Assuming df_all is your DataFrame as defined in the previous code.
results = []

# Loop through independent variables (columns 2-7)
for indep_var in df_all.columns[1:7]:  # Assuming the independent vars start from the second column
    # Loop through dependent variables (columns 9-15)
    for dep_var in df_all.columns[8:15]:
        # Fit the linear regression model
        X = df_all[indep_var]
        y = df_all[dep_var]

        # Add a constant to the independent variable (intercept term)
        X = sm.add_constant(X)

        model = sm.OLS(y, X).fit()

        # Extract p-value and R-squared
        p_value = model.pvalues[indep_var]
        r_squared = model.rsquared

        # Store results
        results.append([indep_var, dep_var, p_value, r_squared])

# Create a DataFrame from the results
results_df = pd.DataFrame(results, columns=['Independent Variable', 'Dependent Variable', 'P-value', 'R-squared'])

results_df

# %% [markdown]
# ## Calculate %change in richness for certain groups and overall between 1900 and 2024, or 1950-2024, etc

# %% [markdown]
# ## Map %change in richness by state

# %% [markdown]
# ## Make nice plots for presentation
# * temp vs year
# * precip vs year
# * temp vs precip
# * temp vs richness (whichever are sig.)
# * precip vs richness (whichever are sig.)
